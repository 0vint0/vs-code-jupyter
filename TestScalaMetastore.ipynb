// %%
%shell "kinit hive/ranger-master-test-m.us-central1-a.c.avid-reference-267100.internal@US-CENTRAL1-A.C.AVID-REFERENCE-267100.INTERNAL -t /etc/security/keytab/hive.service.keytab -k && echo 'Done'"
// Out:
// Done

// %%
spark.sql("show databases").show()
// Out:
// +------------+
// |databaseName|
// +------------+
// |     default|
// |default_test|
// +------------+

// %%
val data = Seq((1,2,3), (4,5,6), (6,7,8), (9,19,10))
val ds = spark.createDataset(data)
ds.show()
// Out:
// +---+---+---+
// | _1| _2| _3|
// +---+---+---+
// |  1|  2|  3|
// |  4|  5|  6|
// |  6|  7|  8|
// |  9| 19| 10|
// +---+---+---+
// data: Seq[(Int, Int, Int)] = List((1,2,3), (4,5,6), (6,7,8), (9,19,10))
// ds: org.apache.spark.sql.Dataset[(Int, Int, Int)] = [_1: int, _2: int ... 1 more field]

// %%
spark.sql("show tables").show()
// Out:
// +--------+---------+-----------+
// |database|tableName|isTemporary|
// +--------+---------+-----------+
// | default| customer|      false|
// +--------+---------+-----------+
